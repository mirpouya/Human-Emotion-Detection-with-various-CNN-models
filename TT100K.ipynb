# %% [markdown]
# <a href="https://colab.research.google.com/github/mirpouya/Human-Emotion-Detection-with-various-CNN-models/blob/main/TT100K.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import pandas as pd
from PIL import Image

# %%
with open("/content/annotations.json", "r") as f:
  data = json.load(f)

# %%
type(data)
# Out:
# dict

# %%
list(data.keys())
# Out:
# ['imgs', 'types']

# %%
data.items()

# %%
list(data.items())

# %%
len(list(data.items()))
# Out:
# 2

# %%
list(data.items())[0]

# %%
list(data.items())[1]

# %%
len(list(data.items())[1][1])
# Out:
# 221

# %%
type(list(data.items())[0])
# Out:
# tuple

# %%
len(list(data.items())[0])
# Out:
# 2

# %%
list(data.items())[0][0]
# Out:
# 'imgs'

# %%
list(data.items())[0][1]

# %%
list(data.items())[0][1]['32773']
# Out:
# {'path': 'test/32773.jpg',
#  'objects': [{'category': 'ph2',
#    'bbox': {'xmin': 924.0,
#     'ymin': 1132.0,
#     'ymax': 1177.3333,
#     'xmax': 966.6667},
#    'ellipse_org': [[942.725, 1132.14],
#     [926.19, 1144.18],
#     [922.884, 1156.61],
#     [931.746, 1173.02],
#     [949.471, 1174.07],
#     [959.921, 1169.58],
#     [962.037, 1142.72]],
#    'ellipse': [[943.6439208984375, 1154.060791015625],
#     [41.572391510009766, 45.09551239013672],
#     36.37429428100586]},
#   {'category': 'p11',
#    'bbox': {'xmin': 970.667,
#     'ymin': 1128.0,
#     'ymax': 1170.6667,
#     'xmax': 1013.3333},
#    'ellipse_org': [[997.385, 1130.51],
#     [977.584, 1137.36],
#     [974.222, 1161.52],
#     [990.286, 1170.61],
#     [1012.7, 1157.41]],
#    'ellipse': [[992.5154418945312, 1149.9034423828125],
#     [39.68983840942383, 43.2476692199707],
#     66.92964172363281]},
#   {'category': 'pl5',
#    'bbox': {'xmin': 1146.67,
#     'ymin': 1108.0,
#     'ymax': 1150.6667,
# ...

# %%
list(data.items())[1]

# %%
temp = list(data.items())[0][1]['32773']

# %%
temp
# Out:
# {'path': 'test/32773.jpg',
#  'objects': [{'category': 'ph2',
#    'bbox': {'xmin': 924.0,
#     'ymin': 1132.0,
#     'ymax': 1177.3333,
#     'xmax': 966.6667},
#    'ellipse_org': [[942.725, 1132.14],
#     [926.19, 1144.18],
#     [922.884, 1156.61],
#     [931.746, 1173.02],
#     [949.471, 1174.07],
#     [959.921, 1169.58],
#     [962.037, 1142.72]],
#    'ellipse': [[943.6439208984375, 1154.060791015625],
#     [41.572391510009766, 45.09551239013672],
#     36.37429428100586]},
#   {'category': 'p11',
#    'bbox': {'xmin': 970.667,
#     'ymin': 1128.0,
#     'ymax': 1170.6667,
#     'xmax': 1013.3333},
#    'ellipse_org': [[997.385, 1130.51],
#     [977.584, 1137.36],
#     [974.222, 1161.52],
#     [990.286, 1170.61],
#     [1012.7, 1157.41]],
#    'ellipse': [[992.5154418945312, 1149.9034423828125],
#     [39.68983840942383, 43.2476692199707],
#     66.92964172363281]},
#   {'category': 'pl5',
#    'bbox': {'xmin': 1146.67,
#     'ymin': 1108.0,
#     'ymax': 1150.6667,
# ...

# %%
temp["objects"]
# Out:
# [{'category': 'ph2',
#   'bbox': {'xmin': 924.0, 'ymin': 1132.0, 'ymax': 1177.3333, 'xmax': 966.6667},
#   'ellipse_org': [[942.725, 1132.14],
#    [926.19, 1144.18],
#    [922.884, 1156.61],
#    [931.746, 1173.02],
#    [949.471, 1174.07],
#    [959.921, 1169.58],
#    [962.037, 1142.72]],
#   'ellipse': [[943.6439208984375, 1154.060791015625],
#    [41.572391510009766, 45.09551239013672],
#    36.37429428100586]},
#  {'category': 'p11',
#   'bbox': {'xmin': 970.667,
#    'ymin': 1128.0,
#    'ymax': 1170.6667,
#    'xmax': 1013.3333},
#   'ellipse_org': [[997.385, 1130.51],
#    [977.584, 1137.36],
#    [974.222, 1161.52],
#    [990.286, 1170.61],
#    [1012.7, 1157.41]],
#   'ellipse': [[992.5154418945312, 1149.9034423828125],
#    [39.68983840942383, 43.2476692199707],
#    66.92964172363281]},
#  {'category': 'pl5',
#   'bbox': {'xmin': 1146.67,
#    'ymin': 1108.0,
#    'ymax': 1150.6667,
#    'xmax': 1190.6733000000002},
#   'ellipse_org': [[1170.5, 1110.58],
# ...

# %%
keys = data.keys()
keys
# Out:
# dict_keys(['imgs', 'types'])

# %%
type(data["types"])
# Out:
# list

# %%
unique_values = list(set(data["types"]))
len(unique_values)
# Out:
# 221

# %% [markdown]
# <h2> Images </h2>

# %%
data["imgs"].keys()

# %%
type(data["imgs"].keys())
# Out:
# dict_keys

# %%
img_ids = list(data["imgs"].keys())
len(img_ids)
# Out:
# 16811

# %% [markdown]
# <h2> a small subset to test </h2>

# %%
img_obj_catg_dict = {}
xmin_dict = {}
xmax_dict = {}
ymin_dict = {}
ymax_dict = {}
images_list = []

# %%
for im in range(50):
  image_id = img_ids.pop()
  if len(data["imgs"][image_id]["objects"]) != 0:
    n_objects = len(data["imgs"][image_id]["objects"])

    for ob in range(n_objects):
      # corresponding_image = Image.open("/content/red/JPEGImages/"+ image_id +'.jpg')
      # width, height = corresponding_image.size

      object_category = data['imgs'][image_id]['objects'][ob]['category']
      c = {image_id : object_category}
      img_obj_catg_dict.update(c)

      # xmin_dict={} update
      x_min = data["imgs"][image_id]["objects"][ob]["bbox"]["xmin"]
      xsmall={image_id : x_min}
      xmin_dict.update(xsmall)

      # xmax_dict={} update
      x_max = data["imgs"][image_id]["objects"][ob]["bbox"]["xmax"]
      xbig = {image_id : x_max}
      xmax_dict.update(xbig)

      # ymin_dict={} update
      y_min = data["imgs"][image_id]["objects"][ob]["bbox"]["ymin"]
      ysmall={image_id : y_min}
      ymin_dict.update(ysmall)

      # ymax_dict={} update
      y_max = data["imgs"][image_id]["objects"][ob]["bbox"]["ymax"]
      ybig = {image_id : y_max}
      ymax_dict.update(ybig)

      images_list.append(image_id)

# %%
imID_sign_df = pd.DataFrame(img_obj_catg_dict.items(), columns=['ImageID', 'sign'])
imID_sign_df.head()
# Out:
#   ImageID  sign
# 0   65521  il60
# 1   22913   w32
# 2   32751    p9
# 3   32743    ip
# 4   87376   w63

# %%
xmin_df = pd.DataFrame(xmin_dict.items(), columns=["ImageID", "XMin"])
xmin_df.head()
# Out:
#   ImageID      XMin
# 0   65521  1172.000
# 1   22913   310.000
# 2   32751   284.000
# 3   32743   164.706
# 4   87376  1136.360

# %%
xmax_df = pd.DataFrame(xmax_dict.items(), columns=["ImageID", "XMax"])
xmax_df.head()
# Out:
#   ImageID       XMax
# 0   65521  1232.0000
# 1   22913   359.0000
# 2   32751   357.0000
# 3   32743   250.9804
# 4   87376  1155.1136

# %%
ymin_df = pd.DataFrame(ymin_dict.items(), columns=["ImageID", "YMin"])
ymin_df.head()
# Out:
#   ImageID      YMin
# 0   65521   730.667
# 1   22913  1008.000
# 2   32751   842.000
# 3   32743   960.784
# 4   87376   975.000

# %%
ymax_df = pd.DataFrame(ymax_dict.items(), columns=["ImageID", "YMax"])
ymax_df.head()
# Out:
#   ImageID       YMax
# 0   65521   788.0006
# 1   22913  1052.0000
# 2   32751   930.0000
# 3   32743  1054.9020
# 4   87376   993.1818

# %%
df_merge_difkey = pd.merge(imID_sign_df, xmin_df , left_on='ImageID', right_on='ImageID')
df_merge_difkey.head()
# Out:
#   ImageID  sign      XMin
# 0   65521  il60  1172.000
# 1   22913   w32   310.000
# 2   32751    p9   284.000
# 3   32743    ip   164.706
# 4   87376   w63  1136.360

# %%
df_merge_difkey1 = pd.merge(df_merge_difkey, xmax_df , left_on='ImageID', right_on='ImageID')
df_merge_difkey1.head()
# Out:
#   ImageID  sign      XMin       XMax
# 0   65521  il60  1172.000  1232.0000
# 1   22913   w32   310.000   359.0000
# 2   32751    p9   284.000   357.0000
# 3   32743    ip   164.706   250.9804
# 4   87376   w63  1136.360  1155.1136

# %%
df_merge_difkey2 = pd.merge(df_merge_difkey1, ymin_df , left_on='ImageID', right_on='ImageID')
df_merge_difkey2.head()
# Out:
#   ImageID  sign      XMin       XMax      YMin
# 0   65521  il60  1172.000  1232.0000   730.667
# 1   22913   w32   310.000   359.0000  1008.000
# 2   32751    p9   284.000   357.0000   842.000
# 3   32743    ip   164.706   250.9804   960.784
# 4   87376   w63  1136.360  1155.1136   975.000

# %%
df_merge_difkey3 = pd.merge(df_merge_difkey2, ymax_df , left_on='ImageID', right_on='ImageID')
df_merge_difkey3.head()
# Out:
#   ImageID  sign      XMin       XMax      YMin       YMax
# 0   65521  il60  1172.000  1232.0000   730.667   788.0006
# 1   22913   w32   310.000   359.0000  1008.000  1052.0000
# 2   32751    p9   284.000   357.0000   842.000   930.0000
# 3   32743    ip   164.706   250.9804   960.784  1054.9020
# 4   87376   w63  1136.360  1155.1136   975.000   993.1818
